# %%
pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.0.2-py2.py3-none-any.whl.metadata (7.8 kB)
# Downloading kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 3.1 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2

# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json

# %%
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_test',
     bootstrap_servers=['13.60.84.55:9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))
# Out:
# WARNING:kafka.coordinator.consumer:group_id is None: disabling auto-commit.

# %%
for c in consumer:
  print(c.value)
# Out:
# {'Index': 'NYA', 'Date': '1979-03-28', 'Open': 606.400024, 'High': 606.400024, 'Low': 606.400024, 'Close': 606.400024, 'Adj Close': 606.400024, 'Volume': 0.0, 'CloseUSD': 606.400024}
# {'Index': 'NYA', 'Date': '1986-03-25', 'Open': 1429.780029, 'High': 1429.780029, 'Low': 1429.780029, 'Close': 1429.780029, 'Adj Close': 1429.780029, 'Volume': 0.0, 'CloseUSD': 1429.780029}
# {'Index': 'GSPTSE', 'Date': '2001-05-10', 'Open': 8111.799805, 'High': 8125.700195, 'Low': 8078.399902, 'Close': 8121.5, 'Adj Close': 8121.5, 'Volume': 16014630000.0, 'CloseUSD': 6740.844999999999}
# {'Index': 'NYA', 'Date': '1982-04-16', 'Open': 711.190002, 'High': 711.190002, 'Low': 711.190002, 'Close': 711.190002, 'Adj Close': 711.190002, 'Volume': 0.0, 'CloseUSD': 711.190002}
# {'Index': 'GDAXI', 'Date': '1998-08-03', 'Open': 5805.069824, 'High': 5813.22998, 'Low': 5720.430176, 'Close': 5774.379883, 'Adj Close': 5774.379883, 'Volume': 0.0, 'CloseUSD': 7044.74345726}
# {'Index': 'N100', 'Date': '2016-01-28', 'Open': 860.340027, 'High': 867.73999, 'Low': 846.330017, 'Close': 852.849976, 'Adj Close': 852.849976, 'Volume': 299941300.0, 'CloseUSD': 1040.47697072}
# {'Index': 'SSMI', 'Date': '2007-10-04', 'Open': 9051.0, 'High': 9099.900391, 'Low': 9037.900391, 'Close': 9053.400391, 'Adj Close': 9053.400391, 'Volume': 69417000.0, 'CloseUSD': 10049.27443401}
# {'Index': 'NYA', 'Date': '2018-12-12', 'Open': 12008.58984, 'High': 12074.91016, 'Low': 11941.82031, 'Close': 11943.29004, 'Adj Close': 11943.29004, 'Volume': 3955890000.0, 'CloseUSD': 11943.29004}
# {'Index': '000001.SS', 'Date': '1999-03-18', 'Open': 1155.270996, 'High': 1160.678955, 'Low': 1147.56897, 'Close': 1151.990967, 'Adj Close': 1151.990967, 'Volume': 0.0, 'CloseUSD': 184.31855472}
# {'Index': 'GDAXI', 'Date': '2016-08-16', 'Open': 10666.71973, 'High': 10737.07031, 'Low': 10634.67969, 'Close': 10676.65039, 'Adj Close': 10676.65039, 'Volume': 63827500.0, 'CloseUSD': 13025.5134758}
# {'Index': 'N225', 'Date': '1989-07-11', 'Open': 33689.30859, 'High': 33799.16016, 'Low': 33664.96875, 'Close': 33746.76953, 'Adj Close': 33746.76953, 'Volume': 0.0, 'CloseUSD': 337.4676953}
# {'Index': 'NSEI', 'Date': '2020-05-28', 'Open': 9364.950195, 'High': 9511.25, 'Low': 9336.5, 'Close': 9490.099609, 'Adj Close': 9490.099609, 'Volume': 837900.0, 'CloseUSD': 94.90099609}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-cfe6e8a9f78c> in <cell line: 1>()
# ----> 1 for c in consumer:
#       2   print(c.value)
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# /usr/local/lib/python3.10/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# /usr/local/lib/python3.10/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# /usr/lib/python3.10/selectors.py in select(self, timeout)
#     467             ready = []
#     468             try:
# --> 469                 fd_event_list = self._selector.poll(timeout, max_ev)
#     470             except InterruptedError:
#     471                 return ready
#
# KeyboardInterrupt:

# %%
for count, i in enumerate(consumer):
  print(count)
  print(i.value)
# Out:
# 0
# {'Name': 'Vaibhav'}
# 1
# {'Name': 'Vaibhav'}
# 2
# {'Name': 'Vaibhav'}
# 3
# {'Name': 'Vaibhav'}
# 4
# {'Name': 'Vaibhav'}
# 5
# {'Name': 'Vaibhav'}
# 6
# {'Name': 'Vaibhav'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-c3e65595b7bc> in <cell line: 1>()
# ----> 1 for count, i in enumerate(consumer):
#       2   print(count)
#       3   print(i.value)
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in __next__(self)
#    1191             return self.next_v1()
#    1192         else:
# -> 1193             return self.next_v2()
#    1194
#    1195     def next_v2(self):
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in next_v2(self)
#    1199                 self._iterator = self._message_generator_v2()
#    1200             try:
# -> 1201                 return next(self._iterator)
#    1202             except StopIteration:
#    1203                 self._iterator = None
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in _message_generator_v2(self)
#    1114     def _message_generator_v2(self):
#    1115         timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116         record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117         for tp, records in six.iteritems(record_map):
#    1118             # Generators are stateful, and it is possible that the tp / records
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in poll(self, timeout_ms, max_records, update_offsets)
#     653         remaining = timeout_ms
#     654         while True:
# --> 655             records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656             if records:
#     657                 return records
#
# /usr/local/lib/python3.10/dist-packages/kafka/consumer/group.py in _poll_once(self, timeout_ms, max_records, update_offsets)
#     700
#     701         timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702         self._client.poll(timeout_ms=timeout_ms)
#     703         # after the long poll, we should check whether the group needs to rebalance
#     704         # prior to returning data so that the group can stabilize faster
#
# /usr/local/lib/python3.10/dist-packages/kafka/client_async.py in poll(self, timeout_ms, future)
#     600                     timeout = max(0, timeout)  # avoid negative timeouts
#     601
# --> 602                 self._poll(timeout / 1000)
#     603
#     604             # called without the lock to avoid deadlock potential
#
# /usr/local/lib/python3.10/dist-packages/kafka/client_async.py in _poll(self, timeout)
#     632
#     633         start_select = time.time()
# --> 634         ready = self._selector.select(timeout)
#     635         end_select = time.time()
#     636         if self._sensors:
#
# /usr/lib/python3.10/selectors.py in select(self, timeout)
#     467             ready = []
#     468             try:
# --> 469                 fd_event_list = self._selector.poll(timeout, max_ev)
#     470             except InterruptedError:
#     471                 return ready
#
# KeyboardInterrupt:

# %%
# Provide AWS credentials
s3 = S3FileSystem(key='***', secret='***')

# %%
for count, i in enumerate(consumer):
  with s3.open("s3://kafka-my-bucket-vaibhav/stock_market_{}.json".format(count),'w') as file:
    json.dump(i.value,file)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-b16e4cb543c5> in <cell line: 1>()
#       1 for count, i in enumerate(consumer):
# ----> 2   with s3.open("s3://kafka-my-bucket-vaibhav/stock_market_{}.json".format(count),'w') as file:
#       3     json.dump(i.value,file)
#
# /usr/local/lib/python3.10/dist-packages/fsspec/spec.py in close(self)
#    2031         else:
#    2032             if not self.forced:
# -> 2033                 self.flush(force=True)
#    2034
#    2035             if self.fs is not None:
#
# /usr/local/lib/python3.10/dist-packages/fsspec/spec.py in flush(self, force)
#    1895                 raise
#    1896
# -> 1897         if self._upload_chunk(final=force) is not False:
#    1898             self.offset += self.buffer.seek(0, 2)
#    1899             self.buffer = io.BytesIO()
#
# /usr/local/lib/python3.10/dist-packages/s3fs/core.py in _upload_chunk(self, final)
#    2385
#    2386         if self.autocommit and final:
# -> 2387             self.commit()
#    2388         else:
#    2389             # update 'upload offset'
#
# /usr/local/lib/python3.10/dist-packages/s3fs/core.py in commit(self)
#    2410                 if self.acl:
#    2411                     kw["ACL"] = self.acl
# -> 2412                 write_result = self._call_s3("put_object", **kw)
#    2413             else:
#    2414                 raise RuntimeError
#
# /usr/local/lib/python3.10/dist-packages/s3fs/core.py in _call_s3(self, method, *kwarglist, **kwargs)
#    2247
#    2248     def _call_s3(self, method, *kwarglist, **kwargs):
# -> 2249         return self.fs.call_s3(method, self.s3_additional_kwargs, *kwarglist, **kwargs)
#    2250
#    2251     def _initiate_upload(self):
#
# /usr/local/lib/python3.10/dist-packages/fsspec/asyn.py in wrapper(*args, **kwargs)
#     116     def wrapper(*args, **kwargs):
#     117         self = obj or args[0]
# --> 118         return sync(self.loop, func, *args, **kwargs)
#     119
#     120     return wrapper
#
# /usr/local/lib/python3.10/dist-packages/fsspec/asyn.py in sync(loop, func, timeout, *args, **kwargs)
#      89     while True:
#      90         # this loops allows thread to get interrupted
# ---> 91         if event.wait(1):
#      92             break
#      93         if timeout is not None:
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     605             signaled = self._flag
#     606             if not signaled:
# --> 607                 signaled = self._cond.wait(timeout)
#     608             return signaled
#     609
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     322             else:
#     323                 if timeout > 0:
# --> 324                     gotit = waiter.acquire(True, timeout)
#     325                 else:
#     326                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
